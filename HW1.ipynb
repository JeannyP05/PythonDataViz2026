# %% [markdown]
# <a href="https://colab.research.google.com/github/JeannyP05/PythonDataViz2026/blob/main/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ปภาวดี เหมาะดี**

# %%
print('673020256-6')
# Out:
# 673020256-6
